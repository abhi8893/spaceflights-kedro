# %% [markdown]
# # Data Processing

# %%
from IPython.display import display as display_nb
import pandas as pd

# %%
catalog

# %%
catalog.list()
# Out:
# ['companies', 'reviews', 'shuttles', 'my_dataset', 'parameters']

# %% [markdown]
# ## `preprocess_companies`

# %%
companies = catalog.load('companies')
companies.head()
# Out:
# 2021-11-11 17:44:06,619 - kedro.io.data_catalog - INFO - Loading data from `companies` (CSVDataSet)...
#       id company_rating       company_location  total_fleet_count  \
# 0  35029           100%                   Niue                4.0
# 1  30292            67%               Anguilla                6.0
# 2  19032            67%     Russian Federation                4.0
# 3   8238            91%               Barbados               15.0
# 4  30342            NaN  Sao Tome and Principe                2.0
#
#   iata_approved
# 0             f
# 1             f
# 2             f
# 3             t
# 4             t

# %%
companies.duplicated().sum()
# Out:
# 26998

# %%
companies.shape
# Out:
# (77096, 5)

# %%
companies.dtypes
# Out:
# id                     int64
# company_rating        object
# company_location      object
# total_fleet_count    float64
# iata_approved         object
# dtype: object

# %%
companies.isna().mean()
# Out:
# id                   0.000000
# company_rating       0.387945
# company_location     0.248132
# total_fleet_count    0.000091
# iata_approved        0.000091
# dtype: float64

# %%
with pd.option_context('display.max_rows', None):
    display_nb(companies[['company_location']].drop_duplicates())
# Out:
#                                         company_location
# 0                                                   Niue
# 1                                               Anguilla
# 2                                     Russian Federation
# 3                                               Barbados
# 4                                  Sao Tome and Principe
# 5                                          Faroe Islands
# 6                                             Micronesia
# 7                                                 Rwanda
# 8                                             Uzbekistan
# 10                                              Kiribati
# 11                                             Nicaragua
# 12                                     Wallis and Futuna
# 13                                                 Malta
# 15                                        United Kingdom
# 17                                               Estonia
# 21                             Bouvet Island (Bouvetoya)
# 26                                             Indonesia
# 27                                            Costa Rica
# 28                                      Marshall Islands
# 30                                                   NaN
# 31                                                 Kenya
# 33                                                Brazil
# 34                                                Guinea
# 35                                                Mexico
# 37                                                Gambia
# 38                                           Isle of Man
# 39                                Bosnia and Herzegovina
# 40                                           Switzerland
# 43                                                  Chad
# 44                                              Pakistan
# 46                                           El Salvador
# 48                                               Lebanon
# 51                                               Andorra
# 54                                                Cyprus
# 55                                          Cook Islands
# 56                                               Denmark
# 65                                               Croatia
# 66                                            Mauritania
# 67                                                Monaco
# 76                                               Tunisia
# 77                                             Gibraltar
# 78                                                Canada
# 83                                              Zimbabwe
# 84                                              Guernsey
# 85                                                France
# 87                                               Reunion
# 88                                                 Niger
# 92                                               Finland
# 96                                              Maldives
# 99                                                 Tonga
# 108                                              Senegal
# 112                                              Ecuador
# 113                                               Uganda
# 118                           Slovakia (Slovak Republic)
# 123                                     Christmas Island
# 127                                              Uruguay
# 132                                           Cape Verde
# 141                                              Grenada
# 143                                             Tanzania
# 153                                                Congo
# 157                                         Turkmenistan
# 165                                                Chile
# 166                                              Bahrain
# 167                                              Vanuatu
# 177                                                 Fiji
# 179                                          Philippines
# 190                                           Montserrat
# 216                                                Nauru
# 217                                               Jersey
# 227                                               Malawi
# 230                                              Ukraine
# 238                                                China
# 257         Antarctica (the territory South of 60 deg S)
# 272                                        French Guiana
# 295                                                 Cuba
# 304                        Holy See (Vatican City State)
# 310                                             Djibouti
# 335                                            Venezuela
# 340                                                 Togo
# 345                                                Ghana
# 347                                     French Polynesia
# 376                                     Papua New Guinea
# 383                                          Puerto Rico
# 404                               Libyan Arab Jamahiriya
# 413                                            Greenland
# 420                                          Afghanistan
# 448                                Palestinian Territory
# 454                             Turks and Caicos Islands
# 470                                            Lithuania
# 479                                              Somalia
# 527                                         Saint Helena
# 544                         Svalbard & Jan Mayen Islands
# 552                                                 Peru
# 584                              Cocos (Keeling) Islands
# 586                                             Suriname
# 628                                              Moldova
# 720                                           San Marino
# 802                                       American Samoa
# 861                                              Vietnam
# 914                                             Portugal
# 932                                 Netherlands Antilles
# 1032                                         Netherlands
# 1043                                               Spain
# 1094                                            Slovenia
# 1175                                           Australia
# 1381                                               Korea
# 1994                                              Latvia
# 2040                                        Burkina Faso
# 2330                                    Pitcairn Islands
# 2874                                        Sierra Leone
# 2907   British Indian Ocean Territory (Chagos Archipe...
# 3195                                        Saint Martin
# 3295                                   Brunei Darussalam
# 3476                                          Madagascar
# 3553                                               Samoa
# 3724                                             Tokelau
# 4160                                              Angola
# 4374                                         New Zealand
# 4645                                     Solomon Islands
# 4660                                             Myanmar
# 4700                                             Liberia
# 6297                                             Morocco
# 7098                                              Jordan
# 7418                                          Seychelles
# 7694                United States Minor Outlying Islands
# 8268                                          Tajikistan
# 8367                                               Qatar
# 8774                                               Sudan
# 9056                                       Liechtenstein
# 9319                                                Iraq
# 10746                                            Algeria
# 11076                                               Iran
# 11358                                             Poland
# 14001                                           Honduras
# 14505                                            Iceland
# 15480                                          Hong Kong
# 16663                                            Eritrea
# 18836                                   Saint Barthelemy
# 18987                                             Tuvalu
# 19585                                     Czech Republic
# 20468                           Central African Republic
# 21015                                             Bhutan
# 21885                          Saint Pierre and Miquelon
# 22448                                            Georgia
# 23023                                              Gabon
# 26748                                              Yemen
# 27147                   Lao People's Democratic Republic
# 27620                                             Guyana
# 31244                           Northern Mariana Islands
# 32269       South Georgia and the South Sandwich Islands
# 34576                                             Serbia
# 34608                                        Timor-Leste
# 34723                                              Macao
# 36796                                           Cambodia
# 37626                        Falkland Islands (Malvinas)
# 38288                                        Saint Lucia
# 41986                                            Bahamas
# 43050                                              Egypt
# 43926                                           Dominica
# 45186                                              India
# 45222                                          Argentina
# 46264                                           Paraguay
# 46273                                              Palau
# 46277                                         Bangladesh
# 50213                                              Benin
# 51838                                  Equatorial Guinea
# 52468                                          Guatemala
# 53113                                            Namibia
# 53741                                            Burundi
# 54564                                Antigua and Barbuda
# 56434                                            Comoros
# 56460                                            Ireland
# 60050                                               Oman
# 60214                                            Bermuda
# 60848                                            Austria
# 65479                                              Aruba
# 66338                                             Turkey
# 67699                                          Sri Lanka
# 68617                                     Western Sahara
# 74013                                         Martinique
# 74448                                          Swaziland
# 75795                           United States of America

# %%
companies[['iata_approved']].drop_duplicates()
# Out:
#      iata_approved
# 0                f
# 3                t
# 8655           NaN

# %% [markdown]
# ### Data checks
#
# - `id`
#      - Check if all integers
# - `company_rating`
#     - Check if follow the pattern '[0-9]{1,2}%'
# - `company_location`
#     - Check if actual location (?)
# - `total_fleet_count`
#     - Check if all float
# - `iata_approved`
#     - Check if values are only `f` or `t`

# %% [markdown]
# ### Data Processing
#
# - `company_rating`
#     - convert to float
# - `iata_approved`
#     - convert to boolean

# %%
companies_proc = companies.copy()

# %%
companies_proc['company_rating'].str.replace('%', '').astype(float)
# Out:
# 0        100.0
# 1         67.0
# 2         67.0
# 3         91.0
# 4          NaN
#          ...
# 77091    100.0
# 77092      NaN
# 77093      NaN
# 77094     80.0
# 77095     98.0
# Name: company_rating, Length: 77096, dtype: float64

# %%
class CompanyPreprocessor:
    
    def __init__(self, copy=True):
        self.copy = copy
    
    @staticmethod
    def _parse_percentage(x: pd.Series)-> pd.Series:
        return x.str.replace('%', '').astype(float)/100
    
    @staticmethod
    def _is_true(x: pd.Series)-> pd.Series:
        return pd.Series(x.map({'t': True, 'f': False}), dtype='boolean')
    
    @staticmethod
    def _deduplicate(df: pd.DataFrame) -> pd.DataFrame:
        return df.drop_duplicates().reset_index(drop=True)
    
    def __call__(self, companies: pd.DataFrame)-> pd.DataFrame:
        if self.copy:
            companies = companies.copy()
            
        companies = self._deduplicate(companies)
        companies['company_rating'] = self._parse_percentage(companies['company_rating'])
        companies['iata_approved'] = self._is_true(companies['iata_approved'])
        
        return companies

# %%
preprocess_companies = CompanyPreprocessor()
preprocess_companies(companies)
# Out:
#           id  company_rating       company_location  total_fleet_count  \
# 0      35029            1.00                   Niue                4.0
# 1      30292            0.67               Anguilla                6.0
# 2      19032            0.67     Russian Federation                4.0
# 3       8238            0.91               Barbados               15.0
# 4      30342             NaN  Sao Tome and Principe                2.0
# ...      ...             ...                    ...                ...
# 50093   1742             NaN              Greenland                1.0
# 50094  15249             NaN       Marshall Islands                1.0
# 50095  44431             NaN                    NaN                1.0
# 50096  25724             NaN                    NaN                1.0
# 50097   8000             NaN                  Chile                2.0
#
#        iata_approved
# 0              False
# 1              False
# 2              False
# 3               True
# 4               True
# ...              ...
# 50093          False
# 50094          False
# 50095          False
# 50096          False
# 50097           True
#
# [50098 rows x 5 columns]

# %% [markdown]
# ## `preprocess_shuttles`

# %%
shuttles = catalog.load('shuttles')
# Out:
# 2021-11-11 19:05:33,354 - kedro.io.data_catalog - INFO - Loading data from `shuttles` (ExcelDataSet)...

# %%
shuttles.head()
# Out:
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew d_check_complete  \
# 0      1.0                   2              strict   1.0                f
# 1      1.0                   2              strict   1.0                t
# 2      1.0                   2            moderate   0.0                f
# 3      3.0                   6              strict   3.0                f
# 4      2.0                   4              strict   2.0                f
#
#   moon_clearance_complete     price  company_id
# 0                       f  $1,325.0       35029
# 1                       f  $1,780.0       30292
# 2                       f  $1,715.0       19032
# 3                       f  $4,770.0        8238
# 4                       f  $2,820.0       30342

# %%
shuttles.duplicated().sum()
# Out:
# 0

# %%
shuttles.isna().mean()
# Out:
# id                         0.000000
# shuttle_location           0.000000
# shuttle_type               0.000000
# engine_type                0.000000
# engine_vendor              0.000000
# engines                    0.000506
# passenger_capacity         0.000000
# cancellation_policy        0.000000
# crew                       0.001933
# d_check_complete           0.000000
# moon_clearance_complete    0.000000
# price                      0.000000
# company_id                 0.000000
# dtype: float64

# %%
shuttles.dtypes
# Out:
# id                           int64
# shuttle_location            object
# shuttle_type                object
# engine_type                 object
# engine_vendor               object
# engines                    float64
# passenger_capacity           int64
# cancellation_policy         object
# crew                       float64
# d_check_complete            object
# moon_clearance_complete     object
# price                       object
# company_id                   int64
# dtype: object

# %%
def show_unique_vals(df):
    '''Show nice formatted unique values in each column'''
    
    uniq_df = (df.apply(lambda col: col.unique())
               .reset_index()
               .rename(columns={'index': 'col', 0:'uniq_vals'})
              )
        
    uniq_df['num_uniq'] = uniq_df['uniq_vals'].apply(len)
    
    with pd.option_context('display.max_colwidth', None):
        display_nb(uniq_df)

# %%
from spaceflights.utils import show_unique_vals # Nice!

# %%
cols = ['shuttle_type', 'engine_type', 'engine_vendor', 'cancellation_policy',
        'd_check_complete', 'moon_clearance_complete']
show_unique_vals(shuttles[cols])
# Out:
#                        col  \
# 0             shuttle_type
# 1              engine_type
# 2            engine_vendor
# 3      cancellation_policy
# 4         d_check_complete
# 5  moon_clearance_complete
#
#                                                                                                                                                                                                                                                                                                                                                                                     uniq_vals  \
# 0  [Type V5, Type V2, Type F5, Type O3, Type V7, Type G0, Type S7, Type Z6, Type F1, Type E3, Type Y4, Type X3, Type W5, Type L7, Type I5, Type Z1, Type T7, Type B7, Type K2, Type N0, Type D1, Type D4, Type P6, Type A7, Type Y7, Type U1, Type L0, Type O7, Type O0, Type S1, Type W4, Type F6, Type D2, Type I2, Type I1, Type O1, Type L2, Type R1, Type C2, Type I7, Type A4, Type U0]
# 1                                                                                                                                                                                                                                                                                                                                                                  [Quantum, Plasma, Nuclear]
# 2                                                                                                                                                                                                                                                                      [ThetaBase Services, Warwick Technology Multinational, Banks, Wood and Phillips, MCW Global, SIT Technology Unlimited]
# 3                                                                                                                                                                                                                                                                                                                                                                [strict, moderate, flexible]
# 4                                                                                                                                                                                                                                                                                                                                                                                      [f, t]
# 5                                                                                                                                                                                                                                                                                                                                                                                         [f]
#
#    num_uniq
# 0        42
# 1         3
# 2         5
# 3         3
# 4         2
# 5         1

# %%
shuttles.head()
# Out:
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew d_check_complete  \
# 0      1.0                   2              strict   1.0                f
# 1      1.0                   2              strict   1.0                t
# 2      1.0                   2            moderate   0.0                f
# 3      3.0                   6              strict   3.0                f
# 4      2.0                   4              strict   2.0                f
#
#   moon_clearance_complete     price  company_id
# 0                       f  $1,325.0       35029
# 1                       f  $1,780.0       30292
# 2                       f  $1,715.0       19032
# 3                       f  $4,770.0        8238
# 4                       f  $2,820.0       30342

# %% [markdown]
# ### Data Processing
#
# - `price`
#     - convert to float
# - `d_check_complete`
#     - convert to bool
# - `moon_clearance_complete`
#     - convert to bool

# %%
class ShuttlesPreprocessor:
    
    def __init__(self, copy=True):
        self.copy = copy
    
    @staticmethod
    def _is_true(x: pd.Series)-> pd.Series:
        return pd.Series(x.map({'t': True, 'f': False}), dtype='boolean')
    
    @staticmethod
    def _parse_money(x: pd.Series)-> pd.Series:
        return x.str.replace(r'[^0-9]', '', regex=True)
    
    @staticmethod
    def _deduplicate(df: pd.DataFrame)-> pd.DataFrame:
        return df.drop_duplicates().reset_index(drop=True)
        
    
    def __call__(self, shuttles: pd.DataFrame)-> pd.DataFrame:
        if self.copy:
            shuttles = shuttles.copy()
        
        shuttles = self._deduplicate(shuttles)
        shuttles['price'] = self._parse_money(shuttles['price'])
        shuttles['d_check_complete'] = self._is_true(shuttles['d_check_complete'])
        shuttles['moon_clearance_complete'] = self._is_true(shuttles['moon_clearance_complete'])
        
        return shuttles

# %%
preprocess_shuttles = ShuttlesPreprocessor()
preprocess_shuttles(shuttles)
# Out:
#           id           shuttle_location shuttle_type engine_type  \
# 0      63561                       Niue      Type V5     Quantum
# 1      36260                   Anguilla      Type V5     Quantum
# 2      57015         Russian Federation      Type V5     Quantum
# 3      14035                   Barbados      Type V5      Plasma
# 4      10036      Sao Tome and Principe      Type V2      Plasma
# ...      ...                        ...          ...         ...
# 77091   4368                   Barbados      Type V5     Quantum
# 77092   2983  Bouvet Island (Bouvetoya)      Type F5     Quantum
# 77093  69684                 Micronesia      Type V5      Plasma
# 77094  21738                 Uzbekistan      Type V5      Plasma
# 77095  72645                      Malta      Type F5     Quantum
#
#             engine_vendor  engines  passenger_capacity cancellation_policy  \
# 0      ThetaBase Services      1.0                   2              strict
# 1      ThetaBase Services      1.0                   2              strict
# 2      ThetaBase Services      1.0                   2            moderate
# 3      ThetaBase Services      3.0                   6              strict
# 4      ThetaBase Services      2.0                   4              strict
# ...                   ...      ...                 ...                 ...
# 77091  ThetaBase Services      2.0                   4            flexible
# 77092  ThetaBase Services      1.0                   1            flexible
# 77093  ThetaBase Services      0.0                   2            flexible
# 77094  ThetaBase Services      1.0                   2            flexible
# 77095  ThetaBase Services      0.0                   2            moderate
#
#        crew  d_check_complete  moon_clearance_complete  price  company_id
# 0       1.0             False                    False  13250       35029
# 1       1.0              True                    False  17800       30292
# 2       0.0             False                    False  17150       19032
# 3       3.0             False                    False  47700        8238
# 4       2.0             False                    False  28200       30342
# ...     ...               ...                      ...    ...         ...
# 77091   2.0              True                    False  41070        6654
# 77092   1.0              True                    False  11690        8000
# 77093   1.0              True                    False  19100       14296
# 77094   1.0              True                    False  21700       27363
# 77095   2.0              True                    False  14550       12542
#
# [77096 rows x 13 columns]

# %% [markdown]
# ## Create Master Table

# %%
catalog.list()
# Out:
# ['companies', 'reviews', 'shuttles', 'my_dataset', 'parameters']

# %%
reviews = catalog.load('reviews')
reviews.head(1)
# Out:
# 2021-11-11 18:28:04,887 - kedro.io.data_catalog - INFO - Loading data from `reviews` (CSVDataSet)...
#    shuttle_id  review_scores_rating  review_scores_comfort  \
# 0       63561                  97.0                   10.0
#
#    review_scores_amenities  review_scores_trip  review_scores_crew  \
# 0                      9.0                10.0                10.0
#
#    review_scores_location  review_scores_price  number_of_reviews  \
# 0                     9.0                 10.0                133
#
#    reviews_per_month
# 0               1.65

# %%
reviews.duplicated().sum()
# Out:
# 0

# %%
shuttles.head(1)
# Out:
#       id shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561             Niue      Type V5     Quantum  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew d_check_complete  \
# 0      1.0                   2              strict   1.0                f
#
#   moon_clearance_complete     price  company_id
# 0                       f  $1,325.0       35029

# %%
companies.head(1)
# Out:
#       id company_rating company_location  total_fleet_count iata_approved
# 0  35029           100%             Niue                4.0             f

# %%
def create_master_table(
    shuttles: pd.DataFrame,
    companies: pd.DataFrame,
    reviews: pd.DataFrame)-> pd.DataFrame:
    '''Combines all data to create a master table'''
    
    rated_shuttles = shuttles.merge(reviews, left_on='id', right_on='shuttle_id')
    master_table = rated_shuttles.merge(companies, left_on='company_id', right_on='id').dropna()

    return master_table

# %%
master_table = create_master_table(shuttles, companies.drop_duplicates(), reviews)

# %%
master_table
# Out:
#         id_x           shuttle_location shuttle_type engine_type  \
# 0      63561                       Niue      Type V5     Quantum
# 1      53260                       Niue      Type V5     Quantum
# 2      51019                       Niue      Type V5     Quantum
# 3      53898                       Niue      Type V5      Plasma
# 4      36260                   Anguilla      Type V5     Quantum
# ...      ...                        ...          ...         ...
# 76454  39094         Russian Federation      Type F5     Quantum
# 76497  20330                 Uzbekistan      Type V5     Quantum
# 76526  16445                  Nicaragua      Type V5      Plasma
# 76584  76469  Bouvet Island (Bouvetoya)      Type V5     Quantum
# 76933  75780         Russian Federation      Type V5      Plasma
#
#                   engine_vendor  engines  passenger_capacity  \
# 0            ThetaBase Services      1.0                   2
# 1      Banks, Wood and Phillips      1.0                   2
# 2            ThetaBase Services      1.0                   2
# 3            ThetaBase Services      3.0                   5
# 4            ThetaBase Services      1.0                   2
# ...                         ...      ...                 ...
# 76454        ThetaBase Services      1.0                   2
# 76497        ThetaBase Services      1.0                   2
# 76526        ThetaBase Services      1.0                   1
# 76584        ThetaBase Services      1.0                   2
# 76933        ThetaBase Services      1.0                   2
#
#       cancellation_policy  crew d_check_complete  ... review_scores_crew  \
# 0                  strict   1.0                f  ...               10.0
# 1                  strict   1.0                f  ...               10.0
# 2                flexible   1.0                f  ...               10.0
# 3                  strict   3.0                f  ...               10.0
# 4                  strict   1.0                t  ...                9.0
# ...                   ...   ...              ...  ...                ...
# 76454              strict   1.0                f  ...               10.0
# 76497            flexible   1.0                f  ...               10.0
# 76526            flexible   3.0                f  ...               10.0
# 76584            moderate   1.0                f  ...               10.0
# 76933              strict   1.0                t  ...               10.0
#
#       review_scores_location  review_scores_price  number_of_reviews  \
# 0                        9.0                 10.0                133
# 1                        9.0                 10.0                 37
# 2                        9.0                  9.0                 10
# 3                        9.0                 10.0                 11
# 4                        9.0                  9.0                  3
# ...                      ...                  ...                ...
# 76454                   10.0                 10.0                  1
# 76497                   10.0                 10.0                  1
# 76526                   10.0                 10.0                  3
# 76584                   10.0                 10.0                  1
# 76933                   10.0                 10.0                  1
#
#        reviews_per_month   id_y  company_rating    company_location  \
# 0                   1.65  35029            100%                Niue
# 1                   0.48  35029            100%                Niue
# 2                   0.15  35029            100%                Niue
# 3                   0.21  35029            100%                Niue
# 4                   0.09  30292             67%            Anguilla
# ...                  ...    ...             ...                 ...
# 76454               1.00  42904             70%  Russian Federation
# 76497               1.00   5701            100%          Costa Rica
# 76526               3.00  13728            100%            Pakistan
# 76584               1.00  41714            100%             Lebanon
# 76933               1.00  47766            100%          Uzbekistan
#
#        total_fleet_count  iata_approved
# 0                    4.0              f
# 1                    4.0              f
# 2                    4.0              f
# 3                    4.0              f
# 4                    6.0              f
# ...                  ...            ...
# 76454                2.0              t
# 76497                1.0              t
# 76526                1.0              f
# 76584                1.0              f
# 76933                1.0              t
#
# [29768 rows x 28 columns]
