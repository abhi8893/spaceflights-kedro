# %% [markdown]
# # Data Science Nodes

# %%
catalog.list()
# Out:
# ['companies',
#  'reviews',
#  'shuttles',
#  'my_dataset',
#  'preprocessed_companies',
#  'preprocessed_shuttles',
#  'master_table',
#  'parameters']

# %%
master_table = catalog.load('master_table')
# Out:
# 2021-11-11 22:16:20,197 - kedro.io.data_catalog - INFO - Loading data from `master_table` (CSVDataSet)...

# %%
master_table.head()
# Out:
#     id_x shuttle_location shuttle_type engine_type             engine_vendor  \
# 0  63561             Niue      Type V5     Quantum        ThetaBase Services
# 1  53260             Niue      Type V5     Quantum  Banks, Wood and Phillips
# 2  51019             Niue      Type V5     Quantum        ThetaBase Services
# 3  53898             Niue      Type V5      Plasma        ThetaBase Services
# 4  36260         Anguilla      Type V5     Quantum        ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      1.0                   2              strict   1.0             False
# 1      1.0                   2              strict   1.0             False
# 2      1.0                   2            flexible   1.0             False
# 3      3.0                   5              strict   3.0             False
# 4      1.0                   2              strict   1.0              True
#
#    ...  review_scores_crew  review_scores_location  review_scores_price  \
# 0  ...                10.0                     9.0                 10.0
# 1  ...                10.0                     9.0                 10.0
# 2  ...                10.0                     9.0                  9.0
# 3  ...                10.0                     9.0                 10.0
# 4  ...                 9.0                     9.0                  9.0
#
#    number_of_reviews  reviews_per_month   id_y  company_rating  \
# 0                133               1.65  35029            1.00
# 1                 37               0.48  35029            1.00
# 2                 10               0.15  35029            1.00
# 3                 11               0.21  35029            1.00
# 4                  3               0.09  30292            0.67
#
#    company_location  total_fleet_count  iata_approved
# 0              Niue                4.0          False
# 1              Niue                4.0          False
# 2              Niue                4.0          False
# 3              Niue                4.0          False
# 4          Anguilla                6.0          False
#
# [5 rows x 28 columns]

# %%
feature_cols = ['engines',
 'passenger_capacity',
 'crew',
 'd_check_complete',
 'moon_clearance_complete',
 'iata_approved',
 'company_rating',
 'review_scores_rating']

# %%
master_table[feature_cols]
# Out:
#        engines  passenger_capacity  crew  d_check_complete  \
# 0          1.0                   2   1.0             False
# 1          1.0                   2   1.0             False
# 2          1.0                   2   1.0             False
# 3          3.0                   5   3.0             False
# 4          1.0                   2   1.0              True
# ...        ...                 ...   ...               ...
# 29763      1.0                   2   1.0             False
# 29764      1.0                   2   1.0             False
# 29765      1.0                   1   3.0             False
# 29766      1.0                   2   1.0             False
# 29767      1.0                   2   1.0              True
#
#        moon_clearance_complete  iata_approved  company_rating  \
# 0                        False          False            1.00
# 1                        False          False            1.00
# 2                        False          False            1.00
# 3                        False          False            1.00
# 4                        False          False            0.67
# ...                        ...            ...             ...
# 29763                    False           True            0.70
# 29764                    False           True            1.00
# 29765                    False          False            1.00
# 29766                    False          False            1.00
# 29767                    False           True            1.00
#
#        review_scores_rating
# 0                      97.0
# 1                      98.0
# 2                      92.0
# 3                      98.0
# 4                      90.0
# ...                     ...
# 29763                 100.0
# 29764                 100.0
# 29765                 100.0
# 29766                 100.0
# 29767                 100.0
#
# [29768 rows x 8 columns]

# %%
import pandas as pd
from typing import Dict, Tuple
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import logging

# %%
parameters = {'features': feature_cols, 'test_size': 0.2, 'random_state': 42}

# %%
def split_data(data: pd.DataFrame, parameters: Dict)-> Tuple:
    '''Splits the data into feature and target training and test sets'''
    
    X = data[parameters['features']]
    y = data['price']
    X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                        test_size=parameters['test_size'], random_state=parameters['random_state'])
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_data(master_table, parameters)

# %%
def train_model(X_train: pd.DataFrame, y_train: pd.Series)-> LinearRegression:
    '''Train the linear regression model'''
    regressor = LinearRegression()
    return regressor.fit(X_train, y_train)

# %%
regressor = train_model(X_train, y_train)
regressor
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([ 3.60364953e+03,  3.05065204e+03, -8.74222216e+02, -2.34421626e+02,
#        -9.09494702e-13, -5.18679591e+02, -5.73049073e+02,  5.42163972e+00])

# %%
def evaluate_model(regressor: LinearRegression, X_test: pd.DataFrame, y_test: pd.DataFrame):
    '''Calculates and logs the coefficient of determination'''
    y_pred = regressor.predict(X_test)
    score = r2_score(y_test, y_pred)
    logger = logging.getLogger()
    logger.info("Model has a coefficient R^2 of %.3f on test_data", score)

# %%
evaluate_model(regressor, X_test, y_test)
# Out:
# 2021-11-11 22:34:40,929 - root - INFO - Model has a coefficient R^2 of 0.194 on test_data
